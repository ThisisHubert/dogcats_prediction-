# %% [markdown]
# ### CNNの学習を行うノートブック

# %% [markdown]
# ライブラリのimport

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D
from keras.layers import Activation,Dropout,Flatten,Dense
from keras.utils import np_utils
from keras.callbacks import EarlyStopping
from keras.callbacks import CSVLogger

# %% [markdown]
# パラメータ設定（変更したらCellメニュー→Run All Belowを忘れないこと）

# %%
w=56
work_dir='data/dogs_cats'
npy_data_base='dogs_cats-data'
npy_labels_base='dogs_cats-labels'
classes=['dogs','cats']
num_classes=len(classes)

weight_file="dogs_cats-weight-w{0}.hd5".format(w)
model_file="dogs_cats-model-w{0}.json".format(w)
history_file="dogs_cats-history-w{0}.csv".format(w)

# %% [markdown]
# train/testデータのnumpy配列ファイルからの読み込みとサイズの確認<br>
# Xは0-1(データ型はfloat16)、yはone-hot encodingにする

# %%
mode="train"
npy_data_file="{0}/{1}-{2}-w{3}.npy".format(work_dir,npy_data_base,mode,w)
npy_labels_file="{0}/{1}-{2}-w{3}.npy".format(work_dir,npy_labels_base,mode,w)
X_train=np.load(npy_data_file).astype("float16")
X_train/=255
y_train=np.load(npy_labels_file)
y_train=np_utils.to_categorical(y_train,num_classes)

mode="test"
npy_data_file="{0}/{1}-{2}-w{3}.npy".format(work_dir,npy_data_base,mode,w)
npy_labels_file="{0}/{1}-{2}-w{3}.npy".format(work_dir,npy_labels_base,mode,w)
X_test=np.load(npy_data_file).astype("float16")
X_test/=255
y_test=np.load(npy_labels_file)
y_test=np_utils.to_categorical(y_test,num_classes) #category each animal using 0100, 1000 etc.

print( X_train.shape )
print( y_train.shape )
print( X_test.shape )
print( y_test.shape )
img_rows=X_train.shape[1]  # Image depth 
img_cols=X_train.shape[2]  # Image width 
img_channels=X_train.shape[3]  
print("image_size:", img_rows, img_cols)
print("image_channels:", img_channels)
# Out:
# (2000, 56, 56, 3)
# (2000, 2)
# (400, 56, 56, 3)
# (400, 2)
# image_size: 56 56
# image_channels: 3

# %% [markdown]
# CNNの構築

# %%
input_shape=(img_rows,img_cols,img_channels) # tuple of the input_shape  
model=Sequential()
model.add(Conv2D(16, (3,3), activation='relu', padding='same',
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.45))
model.add(Conv2D(16, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.45))
model.add(Conv2D(32, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.45))
model.add(Conv2D(32, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.45))
model.add(Flatten()) # Convert to one column data
model.add(Dense(64, activation='relu'))# Fully connected layer of 64 neurons
model.add(Dropout(0.45))
model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 56, 56, 16)        448
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 28, 28, 16)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 28, 28, 16)        2320
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 14, 14, 16)        0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 14, 14, 32)        4640
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 7, 7, 32)          0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 7, 7, 32)          9248
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 3, 3, 32)          0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 3, 3, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 288)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                18496
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 35,282
# Trainable params: 35,282
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# CNNの学習

# %%
# %%time
n_epochs=100
val_split=0.2   
batch_size=128
es=EarlyStopping(monitor='val_loss',patience=4,verbose=1)
cl=CSVLogger(history_file)
model.compile(loss='categorical_crossentropy', optimizer='rmsprop',
              metrics=['accuracy'])
#fit_log=model.fit(X_train, y_train, batch_size=batch_size,
#                  epochs=n_epochs, validation_split=val_split,
#                  callbacks=[cl, es])
fit_log=model.fit(X_train, y_train, batch_size=batch_size,
                  epochs=n_epochs, validation_split=val_split,
                  callbacks=[cl])
# Out:
# Train on 1600 samples, validate on 400 samples
# Epoch 1/100
# 1600/1600 [==============================] - 4s 3ms/step - loss: 0.6813 - acc: 0.5988 - val_loss: 0.7951 - val_acc: 0.0000e+00
# Epoch 2/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6653 - acc: 0.6175 - val_loss: 0.7562 - val_acc: 0.0000e+00
# Epoch 3/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6538 - acc: 0.6275 - val_loss: 0.7898 - val_acc: 0.0000e+00
# Epoch 4/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6485 - acc: 0.6231 - val_loss: 0.8099 - val_acc: 0.0000e+00
# Epoch 5/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.
100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5242 - acc: 0.7325 - val_loss: 0.3628 - val_acc: 0.9450
# Epoch 78/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5149 - acc: 0.7506 - val_loss: 0.3785 - val_acc: 0.9375
# Epoch 79/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5153 - acc: 0.7437 - val_loss: 0.2864 - val_acc: 0.9825
# Epoch 80/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5184 - acc: 0.7444 - val_loss: 0.3696 - val_acc: 0.9375
# Epoch 81/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5220 - acc: 0.7275 - val_loss: 0.2883 - val_acc: 0.9725
# Epoch 82/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5112 - acc: 0.7462 - val_loss: 0.3251 - val_acc: 0.9600
# Epoch 83/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5180 - acc: 0.7300 - val_loss: 0.3523 - val_acc: 0.9400
# Epoch 84/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5036 - acc: 0.7544 - val_loss: 0.4001 - val_acc: 0.9050
# Epoch 85/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.4978 - acc: 0.7525 - val_loss: 0.4062 - val_acc: 0.9075
# Epoch 86/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5179 - acc: 0.7381 - val_loss: 0.3992 - val_acc: 0.9175
# Epoch 87/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5106 - acc: 0.7356 - val_loss: 0.3364 - val_acc: 0.9575
# Epoch 88/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5004 - acc: 0.7425 - val_loss: 0.4533 - val_acc: 0.8675
# Epoch 89/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5111 - acc: 0.7344 - val_loss: 0.3591 - val_acc: 0.9500
# Epoch 90/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5093 - acc: 0.7469 - val_loss: 0.3835 - val_acc: 0.9250
# Epoch 91/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5087 - acc: 0.7494 - val_loss: 0.4615 - val_acc: 0.8600
# Epoch 92/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.4932 - acc: 0.7519 - val_loss: 0.2766 - val_acc: 0.9900
# Epoch 93/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5266 - acc: 0.7256 - val_loss: 0.4642 - val_acc: 0.8575
# Epoch 94/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5070 - acc: 0.7494 - val_loss: 0.3683 - val_acc: 0.9400
# Epoch 95/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5086 - acc: 0.7556 - val_loss: 0.4974 - val_acc: 0.8175
# Epoch 96/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.4888 - acc: 0.7569 - val_loss: 0.4638 - val_acc: 0.8475
# Epoch 97/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.4885 - acc: 0.7563 - val_loss: 0.4546 - val_acc: 0.8500
# Epoch 98/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.4893 - acc: 0.7688 - val_loss: 0.3353 - val_acc: 0.9450
# Epoch 99/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5004 - acc: 0.7512 - val_loss: 0.4755 - val_acc: 0.8075
# Epoch 100/100
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.4886 - acc: 0.7544 - val_loss: 0.3430 - val_acc: 0.9425
# Wall time: 4min 34s

# %% [markdown]
# 学習経過のグラフ描画

# %%
plt.plot(fit_log.history['loss'])
plt.plot(fit_log.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train','valid'], loc='best')
plt.show()

plt.plot(fit_log.history['acc'])
plt.plot(fit_log.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train','valid'], loc='best')
plt.show()

# %% [markdown]
# 学習経過のグラフ描画（このようにhistory_fileから読み出すこともできる）

# %%
h=np.loadtxt(history_file,delimiter=',',skiprows=1)
epoch=h[:,0]
acc=h[:,1]
loss=h[:,2]
val_acc=h[:,3]
val_loss=h[:,4]

plt.plot(epoch,loss)
plt.plot(epoch,val_loss)
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train','valid'], loc='best')
plt.show()

plt.plot(epoch,acc)
plt.plot(epoch,val_acc)
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train','valid'], loc='best')
plt.show()

# %% [markdown]
# テストデータに対する精度(汎化性能の見積もり)

# %%
score=model.evaluate(X_test, y_test, verbose=0)
print('loss=', score[0])
print('accuracy=', score[1])
# Out:
# loss= 0.5735228538513184
# accuracy= 0.7

# %% [markdown]
# modelファイルの保存

# %%
model.save_weights(weight_file)
json_str=model.to_json()
with open(model_file,"w") as f:
    f.write(json_str)

ok=1
if not os.path.exists(weight_file):
    ok=0
if not os.path.exists(model_file):
    ok=0
if ok==1:
    print("OK")
# Out:
# OK
